# %%
import pandas as pd
from datetime import datetime


# Load the CSV file into a DataFrame
df = pd.read_csv(r"C:\Users\מיכאל\Desktop\air bnb germany project\AirbnbBerlin.csv", encoding='latin1')
print(df.head())
# Out:
# C:\Users\מיכאל\AppData\Local\Temp\ipykernel_7508\3872515663.py:6: DtypeWarning: Columns (19,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\מיכאל\Desktop\air bnb germany project\AirbnbBerlin.csv", encoding='latin1')
#    index   Review ID review_date  Reviewer ID Reviewer Name  \
# 0      0  58660447.0  01/03/2016   14876562.0        Dennis
# 1      1         NaN         NaN          NaN           NaN
# 2      2  58663795.0  01/03/2016   49367757.0       Andreea
# 3      3  59003619.0  01/05/2016   46694292.0         Sasha
# 4      4  66845661.0    03-25-16   54542819.0        Yohana
#
#                                             Comments  Listing ID  \
# 0  Very nice, clean appartement! Josh was really ...    10002699
# 1                                                NaN    10002922
# 2  Aki is really nice and friendly. We had an ama...    10006647
# 3  Aki is a very nice dude with a clean place in ...    10006647
# 4  Aki's place was easy to find and located in th...    10006647
#
#                              Listing URL                       Listing Name  \
# 0  https://www.airbnb.com/rooms/10002699  Trendy and peaceful KreuzkÃÂ¶lln
# 1  https://www.airbnb.com/rooms/10002922    Sehr zentrale Wohnung in Berlin
# 2  https://www.airbnb.com/rooms/10006647        Very central and very quite
# 3  https://www.airbnb.com/rooms/10006647        Very central and very quite
# 4  https://www.airbnb.com/rooms/10006647        Very central and very quite
#
#     Host ID  ... Last Review Overall Rating Accuracy Rating  \
# 0  44696672  ...  01/03/2016          100.0             8.0
# 1  45848709  ...         NaN            NaN             NaN
# 2  40791092  ...  02/12/2017           92.0             9.0
# 3  40791092  ...  02/12/2017           92.0             9.0
# 4  40791092  ...  02/12/2017           92.0             9.0
#
#   Cleanliness Rating Checkin Rating Communication Rating Location Rating  \
# 0               10.0            6.0                 10.0            10.0
# 1                NaN            NaN                  NaN             NaN
# 2                8.0            9.0                 10.0            10.0
# 3                8.0            9.0                 10.0            10.0
# 4                8.0            9.0                 10.0            10.0
#
#   Value Rating Instant Bookable Business Travel Ready
# 0         10.0                f                     f
# 1          NaN                f                     f
# 2          9.0                f                     f
# 3          9.0                f                     f
# 4          9.0                f                     f
#
# [5 rows x 47 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456961 entries, 0 to 456960
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   index                  456961 non-null  int64
#  1   Review ID              452805 non-null  float64
#  2   review_date            452805 non-null  object
#  3   Reviewer ID            452805 non-null  float64
#  4   Reviewer Name          452805 non-null  object
#  5   Comments               452595 non-null  object
#  6   Listing ID             456961 non-null  int64
#  7   Listing URL            456961 non-null  object
#  8   Listing Name           456756 non-null  object
#  9   Host ID                456961 non-null  int64
#  10  Host URL               456961 non-null  object
#  11  Host Name              456913 non-null  object
#  12  Host Since             456913 non-null  object
#  13  Host Response Time     398194 non-null  object
#  14  Host Response Rate     398194 non-null  object
#  15  Is Superhost           456913 non-null  object
#  16  neighbourhood          456961 non-null  object
#  17  Neighborhood Group     456961 non-null  object
#  18  City                   456928 non-null  object
#  19  Postal Code            449258 non-null  object
#  20  Country Code           456961 non-null  object
#  21  Country                456961 non-null  object
#  22  Latitude               456961 non-null  float64
#  23  Longitude              456961 non-null  float64
#  24  Is Exact Location      456961 non-null  object
#  25  Property Type          456961 non-null  object
#  26  Room Type              456961 non-null  object
#  27  Accomodates            456961 non-null  int64
#  28  Bathrooms              456018 non-null  float64
#  29  Bedrooms               456244 non-null  float64
#  30  Beds                   456871 non-null  float64
#  31  Square Feet            28675 non-null   float64
#  32  Price                  456961 non-null  object
#  33  Guests Included        456961 non-null  int64
#  34  Min Nights             456961 non-null  int64
#  35  Reviews                456961 non-null  int64
#  36  First Review           452805 non-null  object
#  37  Last Review            452805 non-null  object
#  38  Overall Rating         452242 non-null  float64
#  39  Accuracy Rating        452209 non-null  float64
#  40  Cleanliness Rating     452211 non-null  float64
#  41  Checkin Rating         452188 non-null  float64
#  42  Communication Rating   452205 non-null  float64
#  43  Location Rating        452186 non-null  float64
#  44  Value Rating           452185 non-null  float64
#  45  Instant Bookable       456961 non-null  object
#  46  Business Travel Ready  456961 non-null  object
# dtypes: float64(15), int64(7), object(25)
# memory usage: 163.9+ MB

# %%
def get_column_types(df):
    numeric_columns = df.select_dtypes(include=['number']).columns.tolist()
    object_columns = df.select_dtypes(include=['object']).columns.tolist()
    bool_columns = df.select_dtypes(include=['bool']).columns.tolist()
    return numeric_columns, object_columns , bool_columns

# %%
numeric_columns, object_columns , bool_columns = get_column_types(df)
print("# numeric_columns \n")
print(numeric_columns)
print("\n #object_columns \n")
print(object_columns)
print("\n #boolian_columns \n")
print(bool_columns)
# Out:
# # numeric_columns
#
# ['index', 'Review ID', 'Reviewer ID', 'Listing ID', 'Host ID', 'Latitude', 'Longitude', 'Accomodates', 'Bathrooms', 'Bedrooms', 'Beds', 'Square Feet', 'Guests Included', 'Min Nights', 'Reviews', 'Overall Rating', 'Accuracy Rating', 'Cleanliness Rating', 'Checkin Rating', 'Communication Rating', 'Location Rating', 'Value Rating']
#
#  #object_columns
#
# ['review_date', 'Reviewer Name', 'Comments', 'Listing URL', 'Listing Name', 'Host URL', 'Host Name', 'Host Since', 'Host Response Time', 'Host Response Rate', 'Is Superhost', 'neighbourhood', 'Neighborhood Group', 'City', 'Postal Code', 'Country Code', 'Country', 'Is Exact Location', 'Property Type', 'Room Type', 'Price', 'First Review', 'Last Review', 'Instant Bookable', 'Business Travel Ready']
#
#  #boolian_columns
#
# []

# %%
unique_values = {col: df[col].nunique() for col in object_columns}

# Display the number of unique values for each object column
print("\nNumber of unique values in each object column:")
for col, unique_count in unique_values.items():
    print(f"{col}: {unique_count}")
# Out:
# Number of unique values in each object column:
# review_date: 3000
# Reviewer Name: 57372
# Comments: 437539
# Listing URL: 23536
# Listing Name: 22837
# Host URL: 19772
# Host Name: 6184
# Host Since: 3085
# Host Response Time: 4
# Host Response Rate: 75
# Is Superhost: 2
# neighbourhood: 93
# Neighborhood Group: 12
# City: 59
# Postal Code: 396
# Country Code: 3
# Country: 3
# Is Exact Location: 2
# Property Type: 35
# Room Type: 3
# Price: 528
# First Review: 2382
# Last Review: 1464
# Instant Bookable: 2
# Business Travel Ready: 1

# %%
# Columns to remove because too much unique 
columns_to_remove = [
    'review_date', 'Reviewer Name', 'Listing URL', 'Listing Name', 
     'Host Name' , 'Review ID' , 'Listing ID' , 'Host URL' , 'Reviewer ID' , 'Host ID'  , 'First Review','Last Review'
    , 'Business Travel Ready'
]

# Remove the specified columns
df_reduce = df.drop(columns=columns_to_remove)

# %%
df_reduce.head()
# Out:
#    index                                           Comments  Host Since  \
# 0      0  Very nice, clean appartement! Josh was really ...    09-20-15
# 1      1                                                NaN  10/05/2015
# 2      2  Aki is really nice and friendly. We had an ama...  08/07/2015
# 3      3  Aki is a very nice dude with a clean place in ...  08/07/2015
# 4      4  Aki's place was easy to find and located in th...  08/07/2015
#
#    Host Response Time Host Response Rate Is Superhost    neighbourhood  \
# 0                 NaN                NaN            f      NeukÃÂ¶lln
# 1                 NaN                NaN            f  Prenzlauer Berg
# 2  within a few hours               100%            f            Mitte
# 3  within a few hours               100%            f            Mitte
# 4  within a few hours               100%            f            Mitte
#
#   Neighborhood Group    City Postal Code  ... Min Nights Reviews  \
# 0        NeukÃÂ¶lln  Berlin     12047.0  ...          1       1
# 1             Pankow  Berlin     10405.0  ...          1       0
# 2              Mitte  Berlin     10178.0  ...          1      20
# 3              Mitte  Berlin     10178.0  ...          1      20
# 4              Mitte  Berlin     10178.0  ...          1      20
#
#    Overall Rating  Accuracy Rating Cleanliness Rating Checkin Rating  \
# 0           100.0              8.0               10.0            6.0
# 1             NaN              NaN                NaN            NaN
# 2            92.0              9.0                8.0            9.0
# 3            92.0              9.0                8.0            9.0
# 4            92.0              9.0                8.0            9.0
#
#   Communication Rating  Location Rating  Value Rating  Instant Bookable
# 0                 10.0             10.0          10.0                 f
# 1                  NaN              NaN           NaN                 f
# 2                 10.0             10.0           9.0                 f
# 3                 10.0             10.0           9.0                 f
# 4                 10.0             10.0           9.0                 f
#
# [5 rows x 34 columns]

# %%
print("Host Response Time value counts:")
print(df_reduce["Host Response Time"].value_counts())
df_reduce = df_reduce.drop(columns="Host Response Time")
# Out:
# Host Response Time value counts:
# Host Response Time
# within an hour        275309
# within a few hours     72144
# within a day           44929
# a few days or more      5812
# Name: count, dtype: int64

# %%
print("Country  \n " , df["Country"].value_counts())
df_filtered = df_reduce[~df_reduce['Country'].isin(['United Kingdom', 'Netherlands'])]
# Out:
# Country
#   Country
# Germany           456959
# United Kingdom         1
# Netherlands            1
# Name: count, dtype: int64

# %%
df_filtered["City"].value_counts()
# Out:
# City
# Berlin                                   454246
# Berlin (Kreuzberg)                          375
# Berlin-Wilmersdorf                          227
# Berlin-Mitte                                212
# Berlin - Mitte                              177
# KÃÂ¶penick                                 171
# Berlin, friedrichshain                      165
# Prenzlauer Berg                             137
# Wannsee                                     120
# Friedrichshain                              115
# Berlin-Treptow                              111
# Kleinmachnow                                 87
# Berlin- Charlottenburg                       71
# Baseler StraÃÂe 91 A,12205 Berlin          64
# Berlin - SchÃÂ¶neberg                       60
# Baseler StraÃÂe 91 A, 12205 Berlin         55
# Mitte                                        53
# .                                            47
# 10999 Berlin                                 47
# Woltersdorf                                  41
# Berlin/Steglitz                              33
# Mitte/Kreuzberg                              31
# Berlin, Berlin, DE                           24
# Erkner                                       20
# Hoppegarten                                  16
# Berlin Prenzlauer Berg                       16
# berlin                                       16
# Berlin / Kleinmachnow                        16
# ÃÂÃÂµÃÂÃÂ»ÃÂ¸ÃÂ½                     15
# SchÃÂ¶neberg                                13
# Berlin, Charlottenburg                       12
# Weissensee, Berlin                           11
# Berlin Friedrichshain                        11
# Berlim                                       11
# Berlino                                      11
# Berlin-Tiergarten                             9
# Kreuzberg, Berlin                             8
# *                                             8
# Weissensee                                    8
# BerlÃÂ­n                                     8
# Mitte/Tiergarten                              7
# Berlin NeukÃÂ¶lln                            6
# Berlin-Kreuzberg                              5
# Wilmersdorf                                   4
# Berlin-Friedrichshain                         4
# Potsdam                                       3
# Berlin-Wedding                                3
# Berlin (Wedding)                              2
# Berlin-NeukÃÂ¶lln                            2
# ÃÂÃÂµÃÂÃÂ¿ÃÂ»ÃÂ¯ÃÂ½ÃÂ¿              2
# Hennigsdorf                                   2
# Berlin-Zehlendorf                             1
# Zeuthen                                       1
# Ã¦ÂÂÃ¦ÂÂ                                  1
# Berlin Mitte                                  1
# Berlin, SchÃÂ¶neberg                         1
# Charlottenburg                                1
# MÃÂ¼hlenbecker Land                          1
# Eichwalde                                     1
# Name: count, dtype: int64

# %%
def filter_and_standardize_cities(df, column_name):
    # Standardize the city names to 'Berlin' if they contain 'Berlin'
    df = df.copy()
    
    # Convert all values to string to avoid errors with non-string types
    df.loc[:, column_name] = df[column_name].astype(str)
    
    # Standardize the city names to 'Berlin' if they contain 'Berlin'
    df.loc[:, column_name] = df[column_name].apply(lambda x: 'Berlin' if 'berlin' in x.lower() else x)
    
    # Filter to keep only rows where the city name is now 'Berlin'
    df = df[df[column_name] == 'Berlin']
    
    return df


# Apply the function to standardize and filter
df_filtered = filter_and_standardize_cities(df_filtered, 'City')

# Print the result
print(df_filtered["City"].value_counts()) # only berlin
# Out:
# City
# Berlin    456002
# Name: count, dtype: int64

# %%
df_filtered[["neighbourhood", "Neighborhood Group"]]
# Out:
#           neighbourhood        Neighborhood Group
# 0           NeukÃÂ¶lln               NeukÃÂ¶lln
# 1       Prenzlauer Berg                    Pankow
# 2                 Mitte                     Mitte
# 3                 Mitte                     Mitte
# 4                 Mitte                     Mitte
# ...                 ...                       ...
# 456956   Friedrichshain  Friedrichshain-Kreuzberg
# 456957   Friedrichshain  Friedrichshain-Kreuzberg
# 456958          Wedding                     Mitte
# 456959          Wedding                     Mitte
# 456960          Wedding                     Mitte
#
# [456002 rows x 2 columns]

# %%
# Remove the specified columns
df_filtered = df_filtered.drop(columns="Neighborhood Group")

# %%
df_filtered.head()
# Out:
#    index                                           Comments  Host Since  \
# 0      0  Very nice, clean appartement! Josh was really ...    09-20-15
# 1      1                                                NaN  10/05/2015
# 2      2  Aki is really nice and friendly. We had an ama...  08/07/2015
# 3      3  Aki is a very nice dude with a clean place in ...  08/07/2015
# 4      4  Aki's place was easy to find and located in th...  08/07/2015
#
#   Host Response Rate Is Superhost    neighbourhood    City Postal Code  \
# 0                NaN            f      NeukÃÂ¶lln  Berlin     12047.0
# 1                NaN            f  Prenzlauer Berg  Berlin     10405.0
# 2               100%            f            Mitte  Berlin     10178.0
# 3               100%            f            Mitte  Berlin     10178.0
# 4               100%            f            Mitte  Berlin     10178.0
#
#   Country Code  Country  ...  Min Nights  Reviews Overall Rating  \
# 0           DE  Germany  ...           1        1          100.0
# 1           DE  Germany  ...           1        0            NaN
# 2           DE  Germany  ...           1       20           92.0
# 3           DE  Germany  ...           1       20           92.0
# 4           DE  Germany  ...           1       20           92.0
#
#   Accuracy Rating Cleanliness Rating  Checkin Rating  Communication Rating  \
# 0             8.0               10.0             6.0                  10.0
# 1             NaN                NaN             NaN                   NaN
# 2             9.0                8.0             9.0                  10.0
# 3             9.0                8.0             9.0                  10.0
# 4             9.0                8.0             9.0                  10.0
#
#    Location Rating  Value Rating  Instant Bookable
# 0             10.0          10.0                 f
# 1              NaN           NaN                 f
# 2             10.0           9.0                 f
# 3             10.0           9.0                 f
# 4             10.0           9.0                 f
#
# [5 rows x 32 columns]

# %%
df_filtered["Host Since"].value_counts()
# Define the function to parse dates
def parse_date(date_str):
    for fmt in ('%m-%d-%y', '%m-%d-%Y', '%m/%d/%Y'):
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            continue
    return pd.NaT

# Apply the function to the 'Host Since' column
df_filtered['Host Since'] = df_filtered['Host Since'].apply(parse_date)

# Get today's date
today = pd.to_datetime(datetime.now().date())

# Calculate the number of years from today to each date
def calculate_years_from_today(date):
    if pd.isna(date):
        return None
    delta = today - date
    years = delta.days / 365  # Average year length accounting for leap years
    return years

df_filtered['Years From Today'] = df_filtered['Host Since'].apply(calculate_years_from_today)

print(df_filtered['Host Since'] , df_filtered['Years From Today'])
df_filtered.drop(columns=['Host Since'], inplace=True)
# Out:
# 0        2015-09-20
# 1        2015-10-05
# 2        2015-08-07
# 3        2015-08-07
# 4        2015-08-07
#             ...
# 456956   2013-03-17
# 456957   2013-03-17
# 456958   2015-12-14
# 456959   2015-12-14
# 456960   2015-12-14
# Name: Host Since, Length: 456002, dtype: datetime64[ns] 0          8.859685
# 1          8.818617
# 2          8.980151
# 3          8.980151
# 4          8.980151
#             ...
# 456956    11.370294
# 456957    11.370294
# 456958     8.626968
# 456959     8.626968
# 456960     8.626968
# Name: Years From Today, Length: 456002, dtype: float64

# %%
# !pip install re
# Out:
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re

# %%
import re

def remove_non_alphanumeric(text):
    if isinstance(text, str):  # Check if the text is a string
        # Use regex to keep letters, numbers, hyphens, and spaces
        return re.sub(r'[^a-zA-Z0-9- ]', '', text)
    return text  # Return non-string values unchanged



# Apply the function to all elements in the DataFrame
df_cleaned = df_filtered.apply(lambda col: col.map(remove_non_alphanumeric))

# %%
df_cleaned.head()
# Out:
#    index                                           Comments Host Since  \
# 0      0  Very nice clean appartement Josh was really gr... 2015-09-20
# 1      1                                                NaN 2015-10-05
# 2      2  Aki is really nice and friendly We had an amaz... 2015-08-07
# 3      3  Aki is a very nice dude with a clean place in ... 2015-08-07
# 4      4  Akis place was easy to find and located in the... 2015-08-07
#
#   Host Response Rate Is Superhost    neighbourhood    City Postal Code  \
# 0                NaN            f          Neuklln  Berlin     12047.0
# 1                NaN            f  Prenzlauer Berg  Berlin     10405.0
# 2                100            f            Mitte  Berlin     10178.0
# 3                100            f            Mitte  Berlin     10178.0
# 4                100            f            Mitte  Berlin     10178.0
#
#   Country Code  Country  ...  Reviews  Overall Rating Accuracy Rating  \
# 0           DE  Germany  ...        1           100.0             8.0
# 1           DE  Germany  ...        0             NaN             NaN
# 2           DE  Germany  ...       20            92.0             9.0
# 3           DE  Germany  ...       20            92.0             9.0
# 4           DE  Germany  ...       20            92.0             9.0
#
#   Cleanliness Rating Checkin Rating  Communication Rating  Location Rating  \
# 0               10.0            6.0                  10.0             10.0
# 1                NaN            NaN                   NaN              NaN
# 2                8.0            9.0                  10.0             10.0
# 3                8.0            9.0                  10.0             10.0
# 4                8.0            9.0                  10.0             10.0
#
#    Value Rating  Instant Bookable  Years From Today
# 0          10.0                 f          8.859685
# 1           NaN                 f          8.818617
# 2           9.0                 f          8.980151
# 3           9.0                 f          8.980151
# 4           9.0                 f          8.980151
#
# [5 rows x 33 columns]

# %%
# Get categorical columns
categorical_columns = df_cleaned.select_dtypes(include='object').columns
# Count unique values for each categorical column
unique_counts = {column: df_cleaned[column].nunique() for column in categorical_columns}
unique_counts
# Out:
# {'Comments': 429620,
#  'Host Since': 3085,
#  'Host Response Rate': 75,
#  'Is Superhost': 2,
#  'neighbourhood': 92,
#  'City': 1,
#  'Postal Code': 387,
#  'Country Code': 1,
#  'Country': 1,
#  'Is Exact Location': 2,
#  'Property Type': 35,
#  'Room Type': 3,
#  'Price': 523,
#  'Instant Bookable': 2}

# %%
# convert object Postal Code , price and Host Response Rate columns to int
df_cleaned["Price"] = df_cleaned['Price'].astype(int)
df_cleaned["Host Response Rate"] = df_cleaned["Host Response Rate"].astype(int)
df_cleaned["Postal Code"] = df_cleaned["Host Response Rate"].astype(int)
# drop city and country , Country Code too unique - equal to 1 
df_cleaned.drop(columns=['City', 'Country','Country Code'], inplace=True)
# drop comment colums too unique and contain too many words 
df_cleaned.drop(columns=['Comments'], inplace=True)

# %%
print(df_cleaned['Room Type'].value_counts())
print(df_cleaned['Instant Bookable'].value_counts())
# Out:
# Room Type
# Entire homeapt    201158
# Private room      160189
# Shared room         4432
# Name: count, dtype: int64
# Instant Bookable
# f    202088
# t    163691
# Name: count, dtype: int64

# %%
# check how much apartment in the exact location - real location 
print(df_cleaned['Is Exact Location'].value_counts())
# remove false values 
df_cleaned = df_cleaned [df_cleaned['Is Exact Location'] == 't' ].copy()
df_cleaned.drop(columns=['Is Exact Location'], inplace=True)
# Out:
# Is Exact Location
# t    365779
# f     90223
# Name: count, dtype: int64

# %%
# Frequency count of each property type
value_counts = df_cleaned['Property Type'].value_counts()
print(value_counts)
# Define a threshold for "Other"
threshold = 1000  # Change this value based on your needs
# Create a mapping for property types to "Other" if they are below the threshold
mapping = {k: 'Other' if v < threshold else k for k, v in value_counts.items()}
# Replace values in the DataFrame
df_cleaned['Property Type'] = df_cleaned['Property Type'].map(mapping)
# Display the resulting DataFrame
print("\n add other \n ", df_cleaned['Property Type'].value_counts())


# Frequency count of each neighbourhood 
value_counts = df_cleaned['neighbourhood'].value_counts()
print(value_counts)
# Define a threshold for "Other"
threshold = 2000  # Change this value based on your needs
# Create a mapping for property types to "Other" if they are below the threshold
mapping = {k: 'Other' if v < threshold else k for k, v in value_counts.items()}
# Replace values in the DataFrame
df_cleaned['neighbourhood'] = df_cleaned['neighbourhood'].map(mapping)
# Display the resulting DataFrame
print("\n add other \n ", df_cleaned['neighbourhood'].value_counts())
# Out:
# Property Type
# Apartment               314376
# Loft                     14438
# Condominium              11748
# House                     6361
# Hostel                    4140
# Guest suite               2905
# Serviced apartment        2597
# Townhouse                 1937
# Guesthouse                1694
# Bed and breakfast         1607
# Boutique hotel            1311
# Other                      544
# Bungalow                   452
# Houseboat                  337
# Hotel                      293
# Villa                      289
# Cottage                    227
# Cabin                      119
# Tiny house                  77
# Boat                        67
# Aparthotel                  55
# Castle                      49
# Resort                      43
# Hut                         29
# CamperRV                    24
# Cave                        23
# Train                       21
# Casa particular Cuba         9
# Tipi                         3
# Earth house                  3
# Treehouse                    1
# Name: count, dtype: int64
#
#  add other
#   Property Type
# Apartment             314376
# Loft                   14438
# Condominium            11748
# House                   6361
# Hostel                  4140
# Guest suite             2905
# Other                   2665
# Serviced apartment      2597
# Townhouse               1937
# Guesthouse              1694
# Bed and breakfast       1607
# Boutique hotel          1311
# Name: count, dtype: int64
# neighbourhood
# Prenzlauer Berg      59516
# Mitte                56915
# Kreuzberg            46286
# Friedrichshain       37652
# Neuklln              37336
#                      ...
# Rosenthal               24
# Mrkisches Viertel       14
# Konradshhe              12
# Wilhelmsruh             10
# Wartenberg               5
# Name: count, Length: 91, dtype: int64
#
#  add other
#   neighbourhood
# Prenzlauer Berg    59516
# Mitte              56915
# Kreuzberg          46286
# Friedrichshain     37652
# Neuklln            37336
# Other              31025
# Schneberg          19665
# Wedding            15973
# Charlottenburg     15925
# Moabit             15065
# Wilmersdorf         6812
# Tiergarten          4241
# Pankow              3168
# Tempelhof           2937
# Rummelsburg         2848
# Lichtenberg         2843
# Weiensee            2597
# Westend             2569
# Reinickendorf       2406
# Name: count, dtype: int64

# %%
# Maximum number of unique values to display
max_unique_values = 20

# List of categorical columns
categorical_columns = df_cleaned.select_dtypes(include='object').columns

# Filter columns to include only those with 20 or fewer unique values
filtered_columns = [col for col in categorical_columns if df_cleaned[col].nunique() <= max_unique_values]

# Create separate bar plots for each filtered categorical column
for column in filtered_columns:
    plt.figure(figsize=(8, 6))
    value_counts = df_cleaned[column].value_counts().reset_index()
    value_counts.columns = [column, 'Count']
    sns.barplot(x=column, y='Count', data=value_counts, palette='viridis', hue=None)
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.title(f'Frequency of Each Category in {column}')
    plt.xticks(rotation=45)
    plt.show()
    plt.close()  # Close the plot to free up memory
# Out:
# <div id='5434b753-c4b9-4d2f-a2be-c0814181c3f5'></div>
# C:\Users\מיכאל\AppData\Local\Temp\ipykernel_7508\163111900.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=column, y='Count', data=value_counts, palette='viridis', hue=None)
# <div id='0dbed14b-3b10-4778-b146-fd95939d6197'></div>
# C:\Users\מיכאל\AppData\Local\Temp\ipykernel_7508\163111900.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=column, y='Count', data=value_counts, palette='viridis', hue=None)
# <div id='11874817-26c5-4698-9c82-8d310ec54d3b'></div>
# C:\Users\מיכאל\AppData\Local\Temp\ipykernel_7508\163111900.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=column, y='Count', data=value_counts, palette='viridis', hue=None)
# <div id='575fc5c9-639a-4c37-a666-d1dd7f192c04'></div>
# C:\Users\מיכאל\AppData\Local\Temp\ipykernel_7508\163111900.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=column, y='Count', data=value_counts, palette='viridis', hue=None)

# %%
df_cleaned.head()
# Out:
#          index Host Since Host Response Rate Is Superhost neighbourhood  \
# 0            0   09-20-15                NaN            f       Neuklln
# 2            2   08072015                100            f         Mitte
# 3            3   08072015                100            f         Mitte
# 4            4   08072015                100            f         Mitte
# 5            5   08072015                100            f         Mitte
# ...        ...        ...                ...          ...           ...
# 456952  456952   10082014                100            t     Kreuzberg
# 456953  456953   10082014                100            t     Kreuzberg
# 456958  456958   12-14-15                100            f       Wedding
# 456959  456959   12-14-15                100            f       Wedding
# 456960  456960   12-14-15                100            f       Wedding
#
#        Postal Code Country Code  Latitude  Longitude Property Type  ...  \
# 0          12047.0           DE  52.49234   13.42994     Apartment  ...
# 2          10178.0           DE  52.52134   13.41866     Apartment  ...
# 3          10178.0           DE  52.52134   13.41866     Apartment  ...
# 4          10178.0           DE  52.52134   13.41866     Apartment  ...
# 5          10178.0           DE  52.52134   13.41866     Apartment  ...
# ...            ...          ...       ...        ...           ...  ...
# 456952     10963.0           DE  52.50283   13.37799     Apartment  ...
# 456953     10963.0           DE  52.50283   13.37799     Apartment  ...
# 456958     13355.0           DE  52.53806   13.38776     Apartment  ...
# 456959     13355.0           DE  52.53806   13.38776     Apartment  ...
# 456960     13355.0           DE  52.53806   13.38776     Apartment  ...
#
#        Min Nights  Reviews  Overall Rating  Accuracy Rating  \
# 0               1        1           100.0              8.0
# 2               1       20            92.0              9.0
# 3               1       20            92.0              9.0
# 4               1       20            92.0              9.0
# 5               1       20            92.0              9.0
# ...           ...      ...             ...              ...
# 456952          1      349            98.0             10.0
# 456953          1      349            98.0             10.0
# 456958          6        3            80.0             10.0
# 456959          6        3            80.0             10.0
# 456960          6        3            80.0             10.0
#
#         Cleanliness Rating  Checkin Rating  Communication Rating  \
# 0                     10.0             6.0                  10.0
# 2                      8.0             9.0                  10.0
# 3                      8.0             9.0                  10.0
# 4                      8.0             9.0                  10.0
# 5                      8.0             9.0                  10.0
# ...                    ...             ...                   ...
# 456952                10.0            10.0                  10.0
# 456953                10.0            10.0                  10.0
# 456958                 9.0            10.0                  10.0
# 456959                 9.0            10.0                  10.0
# 456960                 9.0            10.0                  10.0
#
#         Location Rating  Value Rating  Instant Bookable
# 0                  10.0          10.0                 f
# 2                  10.0           9.0                 f
# 3                  10.0           9.0                 f
# 4                  10.0           9.0                 f
# 5                  10.0           9.0                 f
# ...                 ...           ...               ...
# 456952             10.0          10.0                 t
# 456953             10.0          10.0                 t
# 456958              9.0           9.0                 f
# 456959              9.0           9.0                 f
# 456960              9.0           9.0                 f
#
# [365779 rows x 28 columns]
